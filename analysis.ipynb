# %% [markdown]
# # Autoresearch Experiment Analysis (x-transformers)
#
# Analysis of autonomous hyperparameter tuning results from `results.tsv`.
# Metric: **BPC** (bits per character) on enwik8 — lower is better.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the TSV (tab-separated, 5 columns: commit, val_bpc, memory_gb, status, description)
df = pd.read_csv("results.tsv", sep="\t")
df["val_bpc"] = pd.to_numeric(df["val_bpc"], errors="coerce")
df["memory_gb"] = pd.to_numeric(df["memory_gb"], errors="coerce")
df["status"] = df["status"].str.strip().str.upper()

print(f"Total experiments: {len(df)}")
print(f"Columns: {list(df.columns)}")
df.head(10)
# Out:
# Total experiments: 370
# Columns: ['commit', 'val_bpc', 'memory_gb', 'status', 'description']
#     commit   val_bpc  memory_gb   status  \
# 0  d70a8a4  1.654723        1.2     KEEP
# 1  a7f30ff  1.706616        7.5  DISCARD
# 2  a2cfef0  1.589666        2.2     KEEP
# 3  c306589  1.870771        4.4  DISCARD
# 4  895d9c5  1.765267        5.1  DISCARD
# 5  02e13f3  1.458132        2.2     KEEP
# 6  e26040e  1.439029        2.1     KEEP
# 7  d8bb60d  1.463104        1.2  DISCARD
# 8  ccc0105  1.434387        2.2     KEEP
# 9  8408f62  1.422380        2.2     KEEP
#
#                                          description
# 0  baseline (dim=512 depth=6 heads=8 bf16 batch=4...
# 1  SwiGLU + batch=32 accum=1 lr=3e-4 (fewer token...
# 2                   SwiGLU + batch=8 accum=4 lr=3e-4
# 3  dim=768 depth=8 heads=12 GQA(kv=4) SwiGLU (too...
# 4  dim=640 depth=6 heads=10 batch=16 accum=2 (40M...
# 5          lr=5e-4 accum=2 (1618 steps 26.5M tokens)
# 6          lr=1e-3 accum=1 (2911 steps 23.8M tokens)
# 7  batch=4 accum=1 (too noisy 4983 steps 20M tokens)
# 8                add_value_residual=True (ResFormer)
# 9                 shift_tokens=1 (char-level helper)

# %%
counts = df["status"].value_counts()
print("Experiment outcomes:")
print(counts.to_string())

n_keep = counts.get("KEEP", 0)
n_discard = counts.get("DISCARD", 0)
n_crash = counts.get("CRASH", 0)
n_decided = n_keep + n_discard
if n_decided > 0:
    print(f"\nKeep rate: {n_keep}/{n_decided} = {n_keep / n_decided:.1%}")
# Out:
# Experiment outcomes:
# status
# DISCARD    282
# KEEP        60
# CRASH       28
#
# Keep rate: 60/342 = 17.5%

# %%
# Show all KEPT experiments (the improvements that stuck)
kept = df[df["status"] == "KEEP"].copy()
print(f"KEPT experiments ({len(kept)} total):\n")
for i, row in kept.iterrows():
    bpc = row["val_bpc"]
    desc = row["description"]
    print(f"  #{i:3d}  bpc={bpc:.6f}  mem={row['memory_gb']:.1f}GB  {desc}")
# Out:
# KEPT experiments (60 total):
#
#   #  0  bpc=1.654723  mem=1.2GB  baseline (dim=512 depth=6 heads=8 bf16 batch=4 accum=4)
#   #  2  bpc=1.589666  mem=2.2GB  SwiGLU + batch=8 accum=4 lr=3e-4
#   #  5  bpc=1.458132  mem=2.2GB  lr=5e-4 accum=2 (1618 steps 26.5M tokens)
#   #  6  bpc=1.439029  mem=2.1GB  lr=1e-3 accum=1 (2911 steps 23.8M tokens)
#   #  8  bpc=1.434387  mem=2.2GB  add_value_residual=True (ResFormer)
#   #  9  bpc=1.422380  mem=2.2GB  shift_tokens=1 (char-level helper)
#   # 15  bpc=1.403353  mem=1.6GB  dim=384 depth=6 heads=6 (14.4M params 34.4M tokens)
#   # 16  bpc=1.396422  mem=1.4GB  dim=256 depth=8 heads=4 (8.5M params 38.1M tokens)
#   # 24  bpc=1.392207  mem=1.4GB  lr=1.5e-3
#   # 25  bpc=1.391754  mem=1.4GB  lr=2e-3
#   # 35  bpc=1.391472  mem=1.4GB  lr=2.5e-3 warmdown=40%
#   # 37  bpc=1.389661  mem=1.4GB  post_emb_norm=True
#   # 55  bpc=1.384562  mem=1.4GB  softclamp_output + zero_init_branch_output (Gemma2/NeoX)
#   # 63  bpc=1.380904  mem=1.0GB  ff_glu_mult_bias=True (learnable bias in GLU gate - new best!)
#   # 64  bpc=1.369228  mem=1.0GB  emb_frac_gradient=0.1 (GLM-130B reduced embedding gradient - new best!)
#   # 69  bpc=1.361286  mem=1.0GB  attn_laser=True (LASER gradient enhancement - new best!)
#   # 75  bpc=1.348194  mem=1.0GB  lr=3e-3 (higher LR with laser stability - new best!)
#   # 83  bpc=1.292377  mem=1.9GB  batch=16 accum=2 (4x larger effective batch, 136M tokens - new best!)
#   # 84  bpc=1.288839  mem=3.7GB  batch=32 accum=2 (174M tokens - new best!)
#   # 87  bpc=1.287599  mem=3.7GB  lr=5e-3 batch=32 accum=2 (marginal improvement - new best)
#   # 88  bpc=1.283298  mem=3.7GB  lr=6e-3 batch=32 accum=2 (new best!)
#   # 89  bpc=1.282905  mem=3.7GB  lr=8e-3 batch=32 accum=2 (new best!)
#   # 90  bpc=1.280950  mem=3.7GB  lr=1e-2 batch=32 accum=2 (new best!)
#   # 92  bpc=1.280771  mem=3.7GB  lr=1.2e-2 batch=32 accum=2 (new best!)
#   # 95  bpc=1.275955  mem=4.6GB  dim=320 heads=5 13.3M params 139M tokens (new best!)
#   # 96  bpc=1.272629  mem=5.6GB  dim=384 heads=6 19.1M params 118M tokens (new best!)
#   #100  bpc=1.267031  mem=5.6GB  lr=8e-3 dim=384 (new best! bigger model needs lower LR)
#   #103  bpc=1.264975  mem=4.2GB  dim=384 depth=6 14.4M params 154M tokens (new best!)
#   #106  bpc=1.259621  mem=5.0GB  dim=448 depth=6 heads=7 19.6M params 129M tokens (new best!)
#   #122  bpc=1.257779  mem=5.0GB  GRAD_CLIP=1.0 dim=448 (new best!)
#   #132  bpc=1.247415  mem=9.7GB  MAX_SEQ_LEN=2048 longer context (new best! 134M tokens 1023 steps)
#   #135  bpc=1.238786  mem=9.7GB  seq=4096 batch=16 accum=2 (new best! 121M tokens 921 steps, more context wins)
#   #139  bpc=1.236986  mem=9.7GB  lr=6e-3 seq=4096 (new best! slightly lower LR better at longer seq)
#   #142  bpc=1.235054  mem=9.6GB  accum=1 seq=4096 batch=16 (new best! 1716 steps, more updates win)
#   #143  bpc=1.227725  mem=14.3GB  batch=24 accum=1 seq=4096 (new best! 1207 steps 118M tokens)
#   #145  bpc=1.226931  mem=14.3GB  lr=8e-3 batch=24 accum=1 seq=4096 (new best! marginal LR improvement)
#   #152  bpc=1.224298  mem=14.3GB  rotary_xpos=True (xPos RoPE for long-context, new best!)
#   #162  bpc=1.224080  mem=14.3GB  weight_decay=0.1 (marginal improvement, +0.0002)
#   #163  bpc=1.223660  mem=14.3GB  FINAL_LR_FRAC=0.1 (end at 10% of peak, new best!)
#   #167  bpc=1.222782  mem=14.3GB  FINAL_LR_FRAC=0.05 (5% final LR, new best!)
#   #168  bpc=1.222716  mem=14.3GB  FINAL_LR_FRAC=0.02 (marginal new best, trending toward 0)
#   #185  bpc=1.219637  mem=14.3GB  decoupled_wd=True wd=0.001 in optimizer (new best! 1.2196)
#   #195  bpc=1.217106  mem=14.3GB  muon_rms_factor=0.1 (smaller Muon updates, new best!)
#   #198  bpc=1.216706  mem=14.3GB  lr=1e-2 (slightly better than 8e-3 with muon_rms_factor=0.1)
#   #199  bpc=1.208242  mem=14.3GB  muon_beta1=0.9 (less momentum, big improvement!)
#   #203  bpc=1.207870  mem=14.3GB  muon_beta1=0.92 (new best, fine-tuning between 0.9 and 0.95)
#   #247  bpc=1.208619  mem=14.3GB  baseline: best config from mar11 (dim=448 depth=6 heads=7 seq=4096 muon_beta1=0.92)
#   #259  bpc=1.207732  mem=14.3GB  betas=(0.92, 0.99) for AdamAtan2 matching muon_beta1=0.92 (new best!)
#   #273  bpc=1.207534  mem=14.3GB  GRAD_CLIP=0.8 (new best! between 0.5 worse and 1.0)
#   #276  bpc=1.207514  mem=14.3GB  lr=1.1e-2 clip=0.8 (new best! marginal)
#   #278  bpc=1.205890  mem=14.3GB  WARMDOWN_RATIO=0.45 (new best! better than 0.4)
#   #284  bpc=1.205387  mem=14.3GB  WARMDOWN_RATIO=0.47 (marginal new best, fine-tuning 0.45->0.47)
#   #304  bpc=1.210893  mem=14.3GB  baseline (mar13 best: dim=448 depth=6 heads=7 laser xpos swiglu)
#   #323  bpc=1.208069  mem=14.3GB  muon_beta1=0.93 (new best! 1.2081 vs 1.2109 baseline)
#   #328  bpc=1.207620  mem=14.3GB  FINAL_LR_FRAC=0.03 with muon_beta1=0.93 (new best! 1.2076)
#   #333  bpc=1.207577  mem=14.3GB  softclamp_output_value=25 (marginal new best! 1.2076)
#   #347  bpc=1.207334  mem=14.3GB  muon_beta1=0.925 (new best! fine-tune between 0.92 and 0.93)
#   #357  bpc=1.207061  mem=14.3GB  betas=(0.925,0.99) aligned with muon_beta1 (new best!)
#   #359  bpc=1.206617  mem=14.3GB  muon_beta1=0.92 betas=(0.92,0.99) aligned (new best! 1.2066)
#   #360  bpc=1.206540  mem=14.3GB  GRAD_CLIP=0.75 (marginal new best! 1.2065)

# %% [markdown]
# ## Val BPC Over Time
#
# Track how the best (kept) val_bpc evolves as experiments progress.
# The running minimum shows the "frontier" — the best result achieved so far.

# %%
fig, ax = plt.subplots(figsize=(16, 8))

# Filter out crashes for plotting
valid = df[df["status"] != "CRASH"].copy()
valid = valid.reset_index(drop=True)

baseline_bpc = valid.loc[0, "val_bpc"]

# Compute running min from kept experiments (needed for y-axis scaling)
kept_mask = valid["status"] == "KEEP"
kept_idx = valid.index[kept_mask]
kept_bpc = valid.loc[kept_mask, "val_bpc"]
running_min = kept_bpc.cummin()
best = running_min.iloc[-1] if len(running_min) > 0 else baseline_bpc

# Only plot points at or below baseline (the interesting region)
below = valid[valid["val_bpc"] <= baseline_bpc + 0.005]

# Plot discarded as faint background dots
disc = below[below["status"] == "DISCARD"]
ax.scatter(
    disc.index,
    disc["val_bpc"],
    c="#cccccc",
    s=12,
    alpha=0.5,
    zorder=2,
    label="Discarded",
)

# Plot kept experiments as prominent green dots
kept_v = below[below["status"] == "KEEP"]
ax.scatter(
    kept_v.index,
    kept_v["val_bpc"],
    c="#2ecc71",
    s=50,
    zorder=4,
    label="Kept",
    edgecolors="black",
    linewidths=0.5,
)

# Running minimum step line
ax.step(
    kept_idx,
    running_min,
    where="post",
    color="#27ae60",
    linewidth=2,
    alpha=0.7,
    zorder=3,
    label="Running best",
)

# Label each kept experiment with its description
for idx, bpc in zip(kept_idx, kept_bpc):
    desc = str(valid.loc[idx, "description"]).strip()
    if len(desc) > 45:
        desc = desc[:42] + "..."

    ax.annotate(
        desc,
        (idx, bpc),
        textcoords="offset points",
        xytext=(6, 6),
        fontsize=8.0,
        color="#1a7a3a",
        alpha=0.9,
        rotation=30,
        ha="left",
        va="bottom",
    )

n_total = len(df)
n_kept = len(df[df["status"] == "KEEP"])
ax.set_xlabel("Experiment #", fontsize=12)
ax.set_ylabel("Validation BPC (lower is better)", fontsize=12)
ax.set_title(
    f"Autoresearch (x-transformers) Progress: {n_total} Experiments, {n_kept} Kept Improvements",
    fontsize=14,
)
ax.legend(loc="upper right", fontsize=9)
ax.grid(True, alpha=0.2)

# Y-axis: from just below best to just above baseline
margin = max((baseline_bpc - best) * 0.15, 0.002)
ax.set_ylim(best - margin, baseline_bpc + margin)

plt.tight_layout()
plt.savefig("progress.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to progress.png")
# Out:
# Saved to progress.png

# %% [markdown]
# ## Summary Statistics

# %%
# Summary stats
kept = df[df["status"] == "KEEP"].copy()
baseline_bpc = df.iloc[0]["val_bpc"]
best_bpc = kept["val_bpc"].min()
best_row = kept.loc[kept["val_bpc"].idxmin()]

print(f"Baseline val_bpc:  {baseline_bpc:.6f}")
print(f"Best val_bpc:      {best_bpc:.6f}")
print(
    f"Total improvement: {baseline_bpc - best_bpc:.6f} ({(baseline_bpc - best_bpc) / baseline_bpc * 100:.2f}%)"
)
print(f"Best experiment:   {best_row['description']}")
print()

# How many experiments to find each improvement
print("Cumulative effort per improvement:")
kept_sorted = kept.reset_index()
for i, (_, row) in enumerate(kept_sorted.iterrows()):
    desc = str(row["description"]).strip()
    print(f"  Experiment #{row['index']:3d}: bpc={row['val_bpc']:.6f}  {desc}")
# Out:
# Baseline val_bpc:  1.654723
# Best val_bpc:      1.205387
# Total improvement: 0.449336 (27.15%)
# Best experiment:   WARMDOWN_RATIO=0.47 (marginal new best, fine-tuning 0.45->0.47)
#
# Cumulative effort per improvement:
#   Experiment #  0: bpc=1.654723  baseline (dim=512 depth=6 heads=8 bf16 batch=4 accum=4)
#   Experiment #  2: bpc=1.589666  SwiGLU + batch=8 accum=4 lr=3e-4
#   Experiment #  5: bpc=1.458132  lr=5e-4 accum=2 (1618 steps 26.5M tokens)
#   Experiment #  6: bpc=1.439029  lr=1e-3 accum=1 (2911 steps 23.8M tokens)
#   Experiment #  8: bpc=1.434387  add_value_residual=True (ResFormer)
#   Experiment #  9: bpc=1.422380  shift_tokens=1 (char-level helper)
#   Experiment # 15: bpc=1.403353  dim=384 depth=6 heads=6 (14.4M params 34.4M tokens)
#   Experiment # 16: bpc=1.396422  dim=256 depth=8 heads=4 (8.5M params 38.1M tokens)
#   Experiment # 24: bpc=1.392207  lr=1.5e-3
#   Experiment # 25: bpc=1.391754  lr=2e-3
#   Experiment # 35: bpc=1.391472  lr=2.5e-3 warmdown=40%
#   Experiment # 37: bpc=1.389661  post_emb_norm=True
#   Experiment # 55: bpc=1.384562  softclamp_output + zero_init_branch_output (Gemma2/NeoX)
#   Experiment # 63: bpc=1.380904  ff_glu_mult_bias=True (learnable bias in GLU gate - new best!)
#   Experiment # 64: bpc=1.369228  emb_frac_gradient=0.1 (GLM-130B reduced embedding gradient - new best!)
#   Experiment # 69: bpc=1.361286  attn_laser=True (LASER gradient enhancement - new best!)
#   Experiment # 75: bpc=1.348194  lr=3e-3 (higher LR with laser stability - new best!)
#   Experiment # 83: bpc=1.292377  batch=16 accum=2 (4x larger effective batch, 136M tokens - new best!)
#   Experiment # 84: bpc=1.288839  batch=32 accum=2 (174M tokens - new best!)
#   Experiment # 87: bpc=1.287599  lr=5e-3 batch=32 accum=2 (marginal improvement - new best)
#   Experiment # 88: bpc=1.283298  lr=6e-3 batch=32 accum=2 (new best!)
#   Experiment # 89: bpc=1.282905  lr=8e-3 batch=32 accum=2 (new best!)
#   Experiment # 90: bpc=1.280950  lr=1e-2 batch=32 accum=2 (new best!)
#   Experiment # 92: bpc=1.280771  lr=1.2e-2 batch=32 accum=2 (new best!)
#   Experiment # 95: bpc=1.275955  dim=320 heads=5 13.3M params 139M tokens (new best!)
#   Experiment # 96: bpc=1.272629  dim=384 heads=6 19.1M params 118M tokens (new best!)
#   Experiment #100: bpc=1.267031  lr=8e-3 dim=384 (new best! bigger model needs lower LR)
#   Experiment #103: bpc=1.264975  dim=384 depth=6 14.4M params 154M tokens (new best!)
#   Experiment #106: bpc=1.259621  dim=448 depth=6 heads=7 19.6M params 129M tokens (new best!)
#   Experiment #122: bpc=1.257779  GRAD_CLIP=1.0 dim=448 (new best!)
#   Experiment #132: bpc=1.247415  MAX_SEQ_LEN=2048 longer context (new best! 134M tokens 1023 steps)
#   Experiment #135: bpc=1.238786  seq=4096 batch=16 accum=2 (new best! 121M tokens 921 steps, more context wins)
#   Experiment #139: bpc=1.236986  lr=6e-3 seq=4096 (new best! slightly lower LR better at longer seq)
#   Experiment #142: bpc=1.235054  accum=1 seq=4096 batch=16 (new best! 1716 steps, more updates win)
#   Experiment #143: bpc=1.227725  batch=24 accum=1 seq=4096 (new best! 1207 steps 118M tokens)
#   Experiment #145: bpc=1.226931  lr=8e-3 batch=24 accum=1 seq=4096 (new best! marginal LR improvement)
#   Experiment #152: bpc=1.224298  rotary_xpos=True (xPos RoPE for long-context, new best!)
#   Experiment #162: bpc=1.224080  weight_decay=0.1 (marginal improvement, +0.0002)
#   Experiment #163: bpc=1.223660  FINAL_LR_FRAC=0.1 (end at 10% of peak, new best!)
#   Experiment #167: bpc=1.222782  FINAL_LR_FRAC=0.05 (5% final LR, new best!)
#   Experiment #168: bpc=1.222716  FINAL_LR_FRAC=0.02 (marginal new best, trending toward 0)
#   Experiment #185: bpc=1.219637  decoupled_wd=True wd=0.001 in optimizer (new best! 1.2196)
#   Experiment #195: bpc=1.217106  muon_rms_factor=0.1 (smaller Muon updates, new best!)
#   Experiment #198: bpc=1.216706  lr=1e-2 (slightly better than 8e-3 with muon_rms_factor=0.1)
#   Experiment #199: bpc=1.208242  muon_beta1=0.9 (less momentum, big improvement!)
#   Experiment #203: bpc=1.207870  muon_beta1=0.92 (new best, fine-tuning between 0.9 and 0.95)
#   Experiment #247: bpc=1.208619  baseline: best config from mar11 (dim=448 depth=6 heads=7 seq=4096 muon_beta1=0.92)
#   Experiment #259: bpc=1.207732  betas=(0.92, 0.99) for AdamAtan2 matching muon_beta1=0.92 (new best!)
#   Experiment #273: bpc=1.207534  GRAD_CLIP=0.8 (new best! between 0.5 worse and 1.0)
#   Experiment #276: bpc=1.207514  lr=1.1e-2 clip=0.8 (new best! marginal)
#   Experiment #278: bpc=1.205890  WARMDOWN_RATIO=0.45 (new best! better than 0.4)
#   Experiment #284: bpc=1.205387  WARMDOWN_RATIO=0.47 (marginal new best, fine-tuning 0.45->0.47)
#   Experiment #304: bpc=1.210893  baseline (mar13 best: dim=448 depth=6 heads=7 laser xpos swiglu)
#   Experiment #323: bpc=1.208069  muon_beta1=0.93 (new best! 1.2081 vs 1.2109 baseline)
#   Experiment #328: bpc=1.207620  FINAL_LR_FRAC=0.03 with muon_beta1=0.93 (new best! 1.2076)
#   Experiment #333: bpc=1.207577  softclamp_output_value=25 (marginal new best! 1.2076)
#   Experiment #347: bpc=1.207334  muon_beta1=0.925 (new best! fine-tune between 0.92 and 0.93)
#   Experiment #357: bpc=1.207061  betas=(0.925,0.99) aligned with muon_beta1 (new best!)
#   Experiment #359: bpc=1.206617  muon_beta1=0.92 betas=(0.92,0.99) aligned (new best! 1.2066)
#   Experiment #360: bpc=1.206540  GRAD_CLIP=0.75 (marginal new best! 1.2065)

# %% [markdown]
# ## Top Hits (Kept Experiments by Improvement)

# %%
# Each kept experiment's delta is measured vs the previous kept experiment's bpc
# (since experiments are cumulative — each one builds on the last kept state)
kept = df[df["status"] == "KEEP"].copy()
kept["prev_bpc"] = kept["val_bpc"].shift(1)
kept["delta"] = kept["prev_bpc"] - kept["val_bpc"]

# Drop baseline (no delta)
hits = kept.iloc[1:].copy()

# Sort by delta improvement (biggest first)
hits = hits.sort_values("delta", ascending=False)

print(f"{'Rank':>4}  {'Delta':>8}  {'BPC':>10}  Description")
print("-" * 80)
for rank, (_, row) in enumerate(hits.iterrows(), 1):
    print(f"{rank:4d}  {row['delta']:+.6f}  {row['val_bpc']:.6f}  {row['description']}")

print(
    f"\n{'':>4}  {hits['delta'].sum():+.6f}  {'':>10}  TOTAL improvement over baseline"
)
# Out:
# Rank     Delta         BPC  Description
# --------------------------------------------------------------------------------
#    1  +0.131534  1.458132  lr=5e-4 accum=2 (1618 steps 26.5M tokens)
#    2  +0.065057  1.589666  SwiGLU + batch=8 accum=4 lr=3e-4
#    3  +0.055817  1.292377  batch=16 accum=2 (4x larger effective batch, 136M tokens - new best!)
#    4  +0.019103  1.439029  lr=1e-3 accum=1 (2911 steps 23.8M tokens)
#    5  +0.019027  1.403353  dim=384 depth=6 heads=6 (14.4M params 34.4M tokens)
#    6  +0.013092  1.348194  lr=3e-3 (higher LR with laser stability - new best!)
#    7  +0.012007  1.422380  shift_tokens=1 (char-level helper)
#    8  +0.011676  1.369228  emb_frac_gradient=0.1 (GLM-130B reduced embedding gradient - new best!)
#    9  +0.010364  1.247415  MAX_SEQ_LEN=2048 longer context (new best! 134M tokens 1023 steps)
#   10  +0.008629  1.238786  seq=4096 batch=16 accum=2 (new best! 121M tokens 921 steps, more context wins)
#   11  +0.008464  1.208242  muon_beta1=0.9 (less momentum, big improvement!)
#   12  +0.007942  1.361286  attn_laser=True (LASER gradient enhancement - new best!)
#   13  +0.007329  1.227725  batch=24 accum=1 seq=4096 (new best! 1207 steps 118M tokens)
#   14  +0.006931  1.396422  dim=256 depth=8 heads=4 (8.5M params 38.1M tokens)
#   15  +0.005598  1.267031  lr=8e-3 dim=384 (new best! bigger model needs lower LR)
#   16  +0.005354  1.259621  dim=448 depth=6 heads=7 19.6M params 129M tokens (new best!)
#   17  +0.005099  1.384562  softclamp_output + zero_init_branch_output (Gemma2/NeoX)
#   18  +0.004816  1.275955  dim=320 heads=5 13.3M params 139M tokens (new best!)
#   19  +0.004642  1.434387  add_value_residual=True (ResFormer)
#   20  +0.004301  1.283298  lr=6e-3 batch=32 accum=2 (new best!)
#   21  +0.004215  1.392207  lr=1.5e-3
#   22  +0.003658  1.380904  ff_glu_mult_bias=True (learnable bias in GLU gate - new best!)
#   23  +0.003538  1.288839  batch=32 accum=2 (174M tokens - new best!)
#   24  +0.003326  1.272629  dim=384 heads=6 19.1M params 118M tokens (new best!)
#   25  +0.003079  1.219637  decoupled_wd=True wd=0.001 in optimizer (new best! 1.2196)
#   26  +0.002824  1.208069  muon_beta1=0.93 (new best! 1.2081 vs 1.2109 baseline)
#   27  +0.002633  1.224298  rotary_xpos=True (xPos RoPE for long-context, new best!)
#   28  +0.002531  1.217106  muon_rms_factor=0.1 (smaller Muon updates, new best!)
#   29  +0.002056  1.264975  dim=384 depth=6 14.4M params 154M tokens (new best!)
#   30  +0.001955  1.280950  lr=1e-2 batch=32 accum=2 (new best!)
#   31  +0.001932  1.235054  accum=1 seq=4096 batch=16 (new best! 1716 steps, more updates win)
#   32  +0.001842  1.257779  GRAD_CLIP=1.0 dim=448 (new best!)
#   33  +0.001811  1.389661  post_emb_norm=True
#   34  +0.001800  1.236986  lr=6e-3 seq=4096 (new best! slightly lower LR better at longer seq)
#   35  +0.001624  1.205890  WARMDOWN_RATIO=0.45 (new best! better than 0.4)
#   36  +0.001240  1.287599  lr=5e-3 batch=32 accum=2 (marginal improvement - new best)
#   37  +0.000887  1.207732  betas=(0.92, 0.99) for AdamAtan2 matching muon_beta1=0.92 (new best!)
#   38  +0.000878  1.222782  FINAL_LR_FRAC=0.05 (5% final LR, new best!)
#   39  +0.000794  1.226931  lr=8e-3 batch=24 accum=1 seq=4096 (new best! marginal LR improvement)
#   40  +0.000503  1.205387  WARMDOWN_RATIO=0.47 (marginal new best, fine-tuning 0.45->0.47)
#   41  +0.000453  1.391754  lr=2e-3
#   42  +0.000449  1.207620  FINAL_LR_FRAC=0.03 with muon_beta1=0.93 (new best! 1.2076)
#   43  +0.000444  1.206617  muon_beta1=0.92 betas=(0.92,0.99) aligned (new best! 1.2066)
#   44  +0.000420  1.223660  FINAL_LR_FRAC=0.1 (end at 10% of peak, new best!)
#   45  +0.000400  1.216706  lr=1e-2 (slightly better than 8e-3 with muon_rms_factor=0.1)
#   46  +0.000393  1.282905  lr=8e-3 batch=32 accum=2 (new best!)
#   47  +0.000372  1.207870  muon_beta1=0.92 (new best, fine-tuning between 0.9 and 0.95)
#   48  +0.000282  1.391472  lr=2.5e-3 warmdown=40%
#   49  +0.000273  1.207061  betas=(0.925,0.99) aligned with muon_beta1 (new best!)
#   50  +0.000243  1.207334  muon_beta1=0.925 (new best! fine-tune between 0.92 and 0.93)
#   51  +0.000218  1.224080  weight_decay=0.1 (marginal improvement, +0.0002)
#   52  +0.000198  1.207534  GRAD_CLIP=0.8 (new best! between 0.5 worse and 1.0)
#   53  +0.000179  1.280771  lr=1.2e-2 batch=32 accum=2 (new best!)
#   54  +0.000077  1.206540  GRAD_CLIP=0.75 (marginal new best! 1.2065)
#   55  +0.000066  1.222716  FINAL_LR_FRAC=0.02 (marginal new best, trending toward 0)
#   56  +0.000043  1.207577  softclamp_output_value=25 (marginal new best! 1.2076)
#   57  +0.000020  1.207514  lr=1.1e-2 clip=0.8 (new best! marginal)
#   58  -0.000749  1.208619  baseline: best config from mar11 (dim=448 depth=6 heads=7 seq=4096 muon_beta1=0.92)
#   59  -0.005506  1.210893  baseline (mar13 best: dim=448 depth=6 heads=7 laser xpos swiglu)
#
#       +0.448183              TOTAL improvement over baseline

# %% [markdown]
# ## Memory Usage

# %%
fig, ax = plt.subplots(figsize=(12, 4))

valid = df[df["status"] != "CRASH"].copy().reset_index(drop=True)
colors = ["#2ecc71" if s == "KEEP" else "#cccccc" for s in valid["status"]]
ax.bar(valid.index, valid["memory_gb"], color=colors, alpha=0.7, width=0.8)
ax.axhline(y=8.0, color="red", linestyle="--", alpha=0.5, label="VRAM limit (8 GB)")
ax.set_xlabel("Experiment #", fontsize=11)
ax.set_ylabel("Peak Memory (GB)", fontsize=11)
ax.set_title("Peak VRAM Usage Per Experiment", fontsize=13)
ax.legend(fontsize=9)
ax.grid(True, alpha=0.2, axis="y")

plt.tight_layout()
plt.savefig("memory.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to memory.png")
# Out:
# Saved to memory.png
